# %%
from transforms import Deslant
from torchvision.transforms import Compose
from dataset import CTCData

# %%
dataset = CTCData(csv_file='words.csv', 
                  root_dir='/home/jupyter/tutorials/my_projects/word_recognition/words',
                  transform=Compose([
                     Deslant()]))

# %%
import matplotlib.pyplot as plt
plt.imshow(dataset[810]['image'])

# %%
dataset.word_df.file.iloc[100]
# Out:
# 'a01-003-01-03.png'

# %%
from skimage import io
import os
root_dir='/home/jupyter/tutorials/my_projects/word_recognition/words'
im = io.imread(os.path.join(root_dir, dataset.get_folder(dataset.word_df.file.iloc[810]), dataset.word_df.file.iloc[810]))
plt.imshow(im)

# %%
os.mkdir('/home/jupyter/tutorials/my_projects/word_recognition/words/deslanted')
save_path = '/home/jupyter/tutorials/my_projects/word_recognition/words/deslanted'
for i in range(len(dataset)):
    if not os.path.exists(os.path.join(save_path, dataset.get_folder(dataset.word_df.file.iloc[i]))):
        os.makedirs(os.path.join(save_path, dataset.get_folder(dataset.word_df.file.iloc[i])))
    im  = dataset[i]['image']
    io.imsave(os.path.join(save_path, dataset.get_folder(dataset.word_df.file.iloc[i]), dataset.word_df.file.iloc[i]), im)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/a02/a02-120/a02-120-10-04.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/b03/b03-114/b03-114-03-01.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/b04/b04-147/b04-147-00-06.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/b05/b05-055/b05-055-04-10.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/c03/c03-000d/c03-000d-01-06.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/c04/c04-170/c04-170-04-05.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/d03/d03-112/d03-112-01-11.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/d04/d04-071/d04-071-07-05.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/d04/d04-081/d04-081-03-02.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/e06/e06-070/e06-070-09-06.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/f02/f02-040/f02-040-09-09.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/f07/f07-096/f07-096-05-13.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g03/g03-064/g03-064-07-08.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-011g/g06-011g-02-13.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-011o/g06-011o-05-03.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018b/g06-018b-09-10.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018d/g06-018d-07-05.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018f/g06-018f-05-12.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018h/g06-018h-02-12.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018h/g06-018h-07-03.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018j/g06-018j-08-05.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018l/g06-018l-06-05.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018m/g06-018m-07-10.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018o/g06-018o-09-05.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-018p/g06-018p-07-02.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-031m/g06-031m-08-04.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/g06/g06-031o/g06-031o-10-06.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/l07/l07-176/l07-176-01-02.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/l07/l07-176/l07-176-04-06.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/l07/l07-181/l07-181-04-05.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/l07/l07-181/l07-181-04-12.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/m04/m04-216/m04-216-06-05.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/n04/n04-190/n04-190-06-02.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /opt/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: /home/jupyter/tutorials/my_projects/word_recognition/words/deslanted/p06/p06-030/p06-030-08-04.png is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
# Out:
# array([[247, 248, 249, ..., 255, 255, 255],
#        [247, 244, 248, ..., 255, 255, 255],
#        [249, 250, 248, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 247, 248, 248],
#        [255, 255, 255, ..., 244, 247, 244],
#        [255, 255, 255, ..., 248, 248, 244]], dtype=uint8)
